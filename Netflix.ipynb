# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **About the Dataset**
#
# Netflix is a globally recognized streaming service that provides an extensive collection of highly acclaimed TV shows and movies. It is widely used by individuals around the world for their entertainment needs. The main objective of this project is to conduct a comprehensive analysis on the dataset of Netflix TV shows and movies. The dataset utilized for this analysis has been sourced from Kaggle, a popular platform for data science and machine learning enthusiasts. By examining various attributes of Netflix content, such as the type of shows, ratings, duration, and release year, this analysis aims to derive valuable business insights. These insights will subsequently be used to recommend strategies for Netflix to enhance its business presence and growth across different countries.

# %% [markdown]
# ## **Problems**
# The objective of this project is to analyze the dataset of Netflix TV shows and movies in order to provide recommendations for Netflix to expand its business across various countries. By conducting a comprehensive analysis of the given dataset, we aim to extract valuable business insights related to different attributes of Netflix content, including the type of shows, ratings, duration, and release year. This analysis will enable us to understand the preferences and trends among Netflix viewers in different regions. Based on these insights, we will propose measures and strategies that Netflix can implement to effectively target and engage audiences in diverse countries. These recommendations may include suggestions on content acquisition, localization efforts, marketing strategies, and user experience enhancements. The ultimate goal is to empower Netflix with actionable insights that can drive its business growth and success in international markets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# By analyzing this dataset, we can gather insights into the distribution of content types, ratings, durations, release years, and other attributes. These insights can help in understanding viewer preferences, identifying trends, and making informed decisions to enhance Netflix's content library and cater to the diverse needs of its global audience.

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# # **Exploratory Data Analytics**
# Checking Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Convert the date_added column to datetime
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %% [markdown]
# # Check the null values in the dataset

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# It is important to note that the Netflix dataset contains missing values in several columns, indicating a lack of available information for those specific data points. These missing values can potentially impact the analysis and interpretations derived from the dataset. It is recommended to handle these missing values by employing appropriate data preprocessing techniques before conducting any analysis. By addressing the missing values, such as through imputation or dropping rows, the dataset can be made more complete and reliable for accurate analysis and insights. However, if the decision is made to not modify or alter the dataset in any way, it is crucial to acknowledge that the missing values will remain, and any subsequent analysis should take into consideration the potential limitations and uncertainties arising from these missing values.

# %%
df['director'].fillna('No Data Available', inplace=True)
df['cast'].fillna('No Data Available', inplace=True)
df['country'].fillna('No Data Available', inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
df['rating'] = df['rating'].fillna(df['rating'].mode()[0])

# %%
# Fill missing values in numeric columns with mean or custom values
df['release_year'] = df['release_year'].fillna(df['release_year'].mean())
df['duration'] = df['duration'].fillna('Unknown')

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.head(5)
# Out:
#   show_id     type                  title           director  \
# 0      s1    Movie   Dick Johnson Is Dead    Kirsten Johnson
# 1      s2  TV Show          Blood & Water  No Data Available
# 2      s3  TV Show              Ganglands    Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  No Data Available
# 4      s5  TV Show           Kota Factory  No Data Available
#
#                                                 cast            country  \
# 0                                  No Data Available      United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...       South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  No Data Available
# 3                                  No Data Available  No Data Available
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...              India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Data Visulization

# %% [markdown]
# ## **1.Which country has produced the highest number of movies and TV shows in the dataset? Are there any notable variations in content production across different countries?**

# %%
# Count the occurrences of each country in the 'country' column
country_counts = df['country'].value_counts()

# Get the top 10 countries with the highest content production
top_countries = country_counts.head(10)

colors = plt.cm.tab20c(range(len(top_countries)))

# Plot the content production by country with color
plt.figure(figsize=(10, 6))
top_countries.plot(kind='bar', color=colors)
plt.xlabel('Country')
plt.ylabel('Number of Movies and TV Shows')
plt.title('Content Production by Country')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 2.How has the number of TV shows and movies in the Netflix dataset changed over the years? Are there any noticeable trends or patterns?

# %%
# Create a new DataFrame with the release year and type columns
df_year_type = df[['release_year', 'type']]

# Group the data by release year and type and count the occurrences
count_year_type = df_year_type.groupby(['release_year', 'type']).size().unstack()

# Plot the number of TV shows and movies over the years
plt.figure(figsize=(12, 8))
count_year_type.plot(kind='line')
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Number of TV Shows and Movies over the Years')
plt.legend(['Movie', 'TV Show'])
plt.grid(True)
plt.show()

# %% [markdown]
# # 3.What are the most popular genres among Netflix users? How has the popularity of different genres evolved over time?

# %%
# Extract the genres from the 'listed_in' column
df['genres'] = df['listed_in'].apply(lambda x: x.split(','))

# Create a new DataFrame with the exploded genres
df_exploded = df.explode('genres')

# Group the data by genre and count the occurrences
genre_counts = df_exploded['genres'].value_counts()

# Select the top N genres with the highest counts
top_genres = genre_counts.head(10)  # Adjust N to your desired number of top genres

# Sort the genres in descending order of popularity
top_genres = top_genres.sort_values(ascending=True)

# Plot the popularity of genres over time
plt.figure(figsize=(10, 6))
top_genres.plot(kind='barh', color=['#FF5A5F', '#FFB400', '#3DADFF', '#00CC96', '#D4AEFF',
                                   '#8D44AD', '#FF7F40', '#FFD700', '#FF69B4', '#00BFFF'])
plt.xlabel('Count')
plt.ylabel('Genre')
plt.title('Popularity of Genres on Netflix')
plt.grid(True)
plt.show()

# %% [markdown]
# # 4.Which countries have experienced the highest growth in terms of content production on Netflix? Are there any emerging markets worth exploring for further expansion?

# %%
# Filter the DataFrame to include only rows with non-null country values
df_filtered = df.dropna(subset=['country'])

# Count the occurrences of each country and type (TV show or movie) in the DataFrame
country_type_counts = df_filtered.groupby(['country', 'type']).size().unstack()

# Sort the countries based on the total content production
country_type_counts['Total'] = country_type_counts.sum(axis=1)
country_type_counts = country_type_counts.sort_values(by='Total', ascending=False)

# Select the top N countries with the highest total content production
top_countries = country_type_counts.head(10)  # Adjust N to your desired number of top countries

# Plot the growth in content production by country using a stacked bar graph
plt.figure(figsize=(15, 8))
top_countries.drop(columns='Total').plot(kind='barh', stacked=True)
plt.xlabel('Count')
plt.ylabel('Country')
plt.title('Growth in Content Production on Netflix by Country')
plt.legend(title='Type', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.show()

# %% [markdown]
# # 5.Which rating has the highest among all in this dataset ?

# %%
rating_counts = df.groupby('rating')['show_id'].count()
rating_counts
# Out:
# rating
# 66 min         1
# 74 min         1
# 84 min         1
# G             41
# NC-17          3
# NR            79
# PG           287
# PG-13        490
# R            799
# TV-14       2157
# TV-G         220
# TV-MA       3209
# TV-PG        861
# TV-Y         306
# TV-Y7        333
# TV-Y7-FV       6
# UR             3
# Name: show_id, dtype: int64

# %%
# Remove the first three rows from the rating distribution
rating_counts = df['rating'].value_counts().drop(['66 min', '74 min', '84 min'])
plt.figure(figsize=(15, 6))
colors = plt.cm.Set3(np.linspace(0, 1, 14))
bar_plot = rating_counts.plot(kind='bar', color=colors)
bar_plot.set_xlabel("Rating")
bar_plot.set_ylabel("Count")
bar_plot.set_title("Count of Ratings")
for i, v in enumerate(rating_counts):
    bar_plot.text(i, v, str(v), ha='center', va='bottom')
plt.show()

# %% [markdown]
# # 6. Top 10 directors with most movies ?

# %%
top_directors = df.groupby('director')['show_id'].count().sort_values(ascending=False).head(10)
top_directors
# Out:
# director
# No Data Available         2624
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Youssef Chahine             12
# Jay Chapman                 12
# Martin Scorsese             12
# Name: show_id, dtype: int64

# %%
# Remove the first row from the director distribution
director_counts = df['director'].value_counts().drop('No Data Available').head(10)

# Plot the director distribution as a pie chart
plt.figure(figsize=(10, 6))
director_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Director Distribution (Excluding "No Data Available")')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Conclusion
# The analysis of the Netflix TV shows and movies dataset reveals interesting insights about Netflix's growth and global expansion. The data indicates that Netflix has been successful in expanding its user base globally, with a significant number of subscribers both in the US and internationally.
#
# One of the key factors contributing to Netflix's growth is its strategic approach to content selection. By expanding its content library to include a diverse range of international movies and TV shows, Netflix has catered to the preferences and interests of audiences in different countries. This strategy has helped Netflix tap into new markets and attract a larger user base.
#
# Furthermore, the data highlights the importance of understanding regional preferences and tailoring content offerings accordingly. By analyzing viewership trends, genres, and formats across different regions, Netflix can identify emerging markets and potential areas for further expansion.
#
# Overall, the dataset provides valuable insights for Netflix to continue its growth trajectory. By leveraging data-driven strategies, understanding viewership patterns, and adapting to regional preferences, Netflix can further enhance its business and capture new opportunities in the global entertainment industry.

# %% [markdown]
# ![pexels-vie-studio-4439457.jpg](data:image/jpeg;base64,...)
